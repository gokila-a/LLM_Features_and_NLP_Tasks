# %% [markdown]
# <a href="https://colab.research.google.com/github/gokila-a/LLM_Features_and_NLP_Tasks/blob/main/LLM_Features_and_NLP_Tasks_FIXED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nbformat

with open("LLM_Features_and_NLP_Tasks.ipynb", "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

# Remove widget metadata
if "widgets" in nb["metadata"]:
    del nb["metadata"]["widgets"]

with open("LLM_Features_and_NLP_Tasks_FIXED.ipynb", "w", encoding="utf-8") as f:
    nbformat.write(nb, f)

print("Done")
# Out:
# Done
