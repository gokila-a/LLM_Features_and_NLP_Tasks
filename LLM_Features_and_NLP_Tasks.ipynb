# %% [markdown]
# <a href="https://colab.research.google.com/github/gokila-a/LLM_Features_and_NLP_Tasks/blob/main/LLM_Features_and_NLP_Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.9.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
classifier("I did bad in my exam")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'NEGATIVE', 'score': 0.9994276165962219}]

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
classifier("I met my crush today")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.6451224684715271}]

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
classifier("I met my love today")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.9996905326843262}]

# %%
classifier = pipeline("zero-shot-classification")
classifier(
    "today is a election day",
    candidate_labels=["education","politics","business"],
)
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# {'sequence': 'today is a election day',
#  'labels': ['politics', 'business', 'education'],
#  'scores': [0.9885965585708618, 0.007430278230458498, 0.003973253071308136]}

# %%
classifier = pipeline("zero-shot-classification")
classifier(
    "today is a election day",
    candidate_labels=["sports","politics","business"],
)
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# {'sequence': 'today is a election day',
#  'labels': ['politics', 'business', 'sports'],
#  'scores': [0.9881420731544495, 0.007426862139254808, 0.004431119188666344]}

# %%
classifier = pipeline("zero-shot-classification")
classifier(
    "today is a valemtines day",
    candidate_labels=["lovers","death","animals"],
)
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# {'sequence': 'today is a valemtines day',
#  'labels': ['lovers', 'death', 'animals'],
#  'scores': [0.80802983045578, 0.14138756692409515, 0.050582628697156906]}

# %%
generator = pipeline("text-generation")
generator("as of today, I did")
# Out:
# [transformers] No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.9k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/182 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/5.60k [00:00<?, ?B/s]
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'generated_text': 'as of today, I did not have a single problem with this film. I found it to be very exciting and I loved the performances. I think it was the most thrilling film I have seen in a long time. The story was interesting and the acting was top-notch. I would recommend this film to anyone who enjoys a good thriller. It is a film that will keep you on the edge of your seat.\nA good thriller with a nice twist ending that will keep you on the edge of your seat. I love films like this that make you think and make you question reality. I would highly recommend this film to anyone who likes thrillers and suspense.\nThis film is a very entertaining and thrilling movie. The story is interesting and the acting is great. I like how the film builds suspense and tension as it goes on. The ending is also very surprising. I would definitely recommend this film to anyone who likes thrillers and suspense.\nThis film is a very good thriller with a great plot. The acting is also great and the direction is good. I like how the film keeps you on the edge of your seat. The ending is also very surprising. I would definitely recommend this film to anyone who likes thrillers and suspense.\nThis film is a very good thriller with a great plot. The acting is'}]

# %%
generator = pipeline("text-generation",model="sapientinc/HRM-Text-1B")
generator(
    "as of today, I did",
    max_length=20,
    num_return_sequences=3,
    )
# Out:
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.37G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/131 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/326 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.73M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'generated_text': 'as of today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did'},
#  {'generated_text': 'as of today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did'},
#  {'generated_text': 'as of today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did today, I did'}]

# %%
generator = pipeline("fill-mask")
generator(
    "<mask> is king of forest "
)
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/106 [00:00<?, ?it/s]
# [transformers] RobertaForMaskedLM LOAD REPORT from: distilbert/distilroberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.bias   | UNEXPECTED |  |
# roberta.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [{'score': 0.022664694115519524,
#   'token': 15724,
#   'token_str': 'God',
#   'sequence': 'God is king of forest '},
#  {'score': 0.021568244323134422,
#   'token': 6407,
#   'token_str': 'Man',
#   'sequence': 'Man is king of forest '},
#  {'score': 0.012531700544059277,
#   'token': 894,
#   'token_str': 'He',
#   'sequence': 'He is king of forest '},
#  {'score': 0.01114723738282919,
#   'token': 8453,
#   'token_str': ' king',
#   'sequence': ' king is king of forest '},
#  {'score': 0.01080064196139574,
#   'token': 12375,
#   'token_str': 'Who',
#   'sequence': 'Who is king of forest '}]

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
import torch

tokenizer = AutoTokenizer.from_pretrained("timpal0l/mdeberta-v3-base-squad2")
model = AutoModelForQuestionAnswering.from_pretrained("timpal0l/mdeberta-v3-base-squad2")

context = "i am from coimbatore,myself Gokila studying in KCE "
question = "what am i ?"

inputs = tokenizer(question, context, return_tensors="pt")
with torch.no_grad():
    outputs = model(**inputs)

answer_start_index = outputs.start_logits.argmax()
answer_end_index = outputs.end_logits.argmax() + 1

answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(inputs["input_ids"][0][answer_start_index:answer_end_index]))
print(f"Question: {question}")
print(f"Context: {context}")
print(f"Answer: {answer}")
# Out:
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]
# Question: what am i ?
# Context: i am from coimbatore,myself Gokila studying in KCE
# Answer: Gokila

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-fr")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-fr")

text_to_translate = "I am gokila from Coimbatore."

inputs = tokenizer(text_to_translate, return_tensors="pt")
outputs = model.generate(**inputs)
translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(f"Original text: {text_to_translate}")
print(f"Translated text (French): {translated_text}")
# Out:
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# Original text: I am gokila from Coimbatore.
# Translated text (French): Je suis Gokila de Coimbatore.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

tokenizer = AutoTokenizer.from_pretrained("facebook/bart-large-cnn")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/bart-large-cnn")

text_to_summarize = """Your task is to generate JSON. You are provided with a schema and an incomplete JSON instance. You must complete the JSON instance according to the schema. Do not output anything else. If a field's type is array, and the incomplete JSON does not already contain an array for this field, you can generate an empty array if there are no items to add. If a field's type is string, and the incomplete JSON does not already contain a string for this field, you can generate an empty string if there are no characters to add. Do not generate null values for required fields. Your entire response must be a valid JSON instance. The example responses are for illustrative purposes only, and may not fully conform to the schema as they are not used to generate JSON. However, your response must be valid JSON according to the schema.Your task is to generate JSON. You are provided with a schema and an incomplete JSON instance. You must complete the JSON instance according to the schema. Do not output anything else. If a field's type is array, and the incomplete JSON does not already contain an array for this field, you can generate an empty array if there are no items to add. If a field's type is string, and the incomplete JSON does not already contain a string for this field, you can generate an empty string if there are no characters to add. Do not generate null values for required fields. Your entire response must be a valid JSON instance. The example responses are for illustrative purposes only, and may not fully conform to the schema as they are not used to generate JSON. However, your response must be valid JSON according to the schema."""

# Encode the text
inputs = tokenizer(text_to_summarize, return_tensors="pt", max_length=1024, truncation=True)

# Generate summary
summary_ids = model.generate(
    inputs["input_ids"],
    num_beams=4,
    min_length=25,
    max_length=50,
    early_stopping=True,
    do_sample=False
)

summary_text = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

print(f"Original text: {text_to_summarize[:200]}...")
print(f"Summary: {summary_text}")
# Out:
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# [transformers] Please make sure the generation config includes `forced_bos_token_id=0`.
# Loading weights:   0%|          | 0/511 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Original text: Your task is to generate JSON. You are provided with a schema and an incomplete JSON instance. You must complete the JSON instance according to the schema. Do not output anything else. If a field's ty...
# Summary: Your task is to generate JSON. You are provided with a schema and an incomplete JSON instance. You must complete the JSON instance according to the Schema. Do not generate null values for required fields. Your entire response must be a valid

# %%
from transformers import pipeline
generator = pipeline("ner")
generator(
    "my name is Gokila"
)
# Out:
# [transformers] No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# [{'entity': 'I-PER',
#   'score': np.float32(0.9991185),
#   'index': 4,
#   'word': 'Go',
#   'start': 11,
#   'end': 13},
#  {'entity': 'I-PER',
#   'score': np.float32(0.99657357),
#   'index': 5,
#   'word': '##ki',
#   'start': 13,
#   'end': 15},
#  {'entity': 'I-PER',
#   'score': np.float32(0.9877364),
#   'index': 6,
#   'word': '##la',
#   'start': 15,
#   'end': 17}]
